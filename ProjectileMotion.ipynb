# %%
# @title
#Hyunje Kim#
import matplotlib.pyplot as plt
import matplotlib.animation as animation
import numpy as np, math
from IPython.display import HTML
#Spherical Object Details:
D = 0.07 #{m}
ρ = 7800 #{kg/m³}
V = (4/3)*math.pi*(D/2)**3
#Constants:
g = 9.8       #{m/s²}
m = ρ * V     #{kg}
γ = 0.25      #{Ns²/m⁴}
λ = 10000     #{m}
c = γ * D**2  #drag coefficient
#Initial Conditions:
x = 0  #{m}
y = 0  #{m}
v0 = 300              #{m/s}
θ = math.radians(50)  #{rad}
#Time {s} Parameter:
Δt = 0.01
tf = 35
#Velocity Components:
vx = v0 * math.cos(θ)
vy = v0 * math.sin(θ)
#____________________________Velocity Verlet________________________________________________
#_____________________Drag Function {c(y) = γD²e^(-y/λ)}____________
vx_cont = vx
vy_cont = vy
#pos arrays
x_cont = 0
y_cont = 0
X_cont = [x_cont]
Y_cont = [y_cont]
#drag function
c_y = c * math.exp(-y_cont/λ)
#acc comp.
ax_cont = -c_y*v0*vx_cont/m
ay_cont = -g -(c_y*v0*vy_cont/m)
#time parameter
t_cont = 0.01
while t_cont < tf and y_cont > -1:
    #Velocity Verlet Algorithm
    #1)New Position
    x_cont += vx_cont*t_cont + (0.5 * t_cont**2 * ax_cont)
    y_cont += vy_cont*t_cont + (0.5 * t_cont**2 * ay_cont)
    X_cont.append(x_cont)
    Y_cont.append(y_cont)
    c_y = c * math.exp(-y_cont/λ)
    #2)Temporary New Acceleration(old vel, new pos)
    θ1 = math.atan(y_cont/x_cont)               #Updating the angular component of pos & vel
    v_cont = math.sqrt(vx_cont ** 2 + vy_cont ** 2)  # Updating total velocity magnitude
    temp_ax_cont = -c_y*v_cont*v_cont*math.cos(θ1)/m
    temp_ay_cont = -g -(c_y*v_cont*v_cont*math.sin(θ1)/m)
    #3)Temporary New Velocity(temp acc, old acc)
    temp_vx_cont = vx_cont + ((0.5*t_cont)*(temp_ax_cont + ax_cont))
    temp_vy_cont = vy_cont + ((0.5*t_cont)*(temp_ay_cont + ay_cont))
    temp_v_cont = math.sqrt(temp_vx_cont**2 + temp_vy_cont**2)
    #4)New Acceleration(old vel, new pos)
    new_ax_cont = -c_y*temp_v_cont*temp_vx_cont/m
    new_ay_cont = -g -(c_y*temp_v_cont*temp_vy_cont/m)
    #5)New Velocity(new acc, old acc)
    vx_cont = vx_cont + ((0.5*t_cont)*(new_ax_cont + ax_cont))
    vy_cont = vy_cont + ((0.5*t_cont)*(new_ay_cont + ay_cont))
    #6)Acceleration Reassignment
    ax_cont = new_ax_cont
    ay_cont = new_ay_cont
    t_cont += Δt
  #______________________________Drag Coefficient {c = γD²}______________________________
#Velocity,Net Distances, & Acceleration Components
vx_c = vx
vy_c = vy
#Arrays
x_c = 0
y_c = 0
X_c = [x_c]
Y_c = [y_c]
#Acceleration Components
ax_c = -c*v0*vx_c/m
ay_c = -g -(c*v0*vy_c/m)
t_c = 0.01
while t_c < tf and y_c > -1:
    #Velocity Verlet:
    #1)New Position
    x_c += vx_c*t_c + (0.5 * t_c**2 * ax_c)
    y_c += vy_c*t_c + (0.5 * t_c**2 * ay_c)
    X_c.append(x_c)
    Y_c.append(y_c)
    #2)Temporary New Acceleration(old vel, new pos)
    θ2 = math.atan(y_c/x_c)              #Updating the angular component of pos & vel
    v_c = math.sqrt(vx_c ** 2 + vy_c ** 2)
    temp_ax_c = -c*v_c*v_c*math.cos(θ2)/m
    temp_ay = -g -(c*v_c*v_c*math.sin(θ2)/m)
    #3)Temporary New Velocity(temp acc, old acc)
    temp_vx_c = vx_c + ((0.5*t_c)*(temp_ax_c + ax_c))
    temp_vy_c = vy_c + ((0.5*t_c)*(temp_ay + ay_c))
    temp_v_c = math.sqrt(temp_vx_c ** 2 + temp_vy_c ** 2)
    #4)New Acceleration(old vel, new pos)
    new_ax_c = -c*temp_v_c*temp_vx_c/m
    #5)New Velocity(new acc, old acc)
    new_ay_c = -g -(c*temp_v_c*temp_vy_c/m)
    vx_c = vx_c + ((0.5*t_c)*(new_ax_c + ax_c))
    vy_c = vy_c + ((0.5*t_c)*(new_ay_c + ay_c))
    #6)Acceleration Reassignment
    ax_c = new_ax_c
    ay_c = new_ay_c
    t_c += Δt
#______________________________No Drag {c=0}______________________________
#Time Intervals
vx_vac = vx
vy_vac = vy
#Position & Arrays
x_vac = 0
y_vac = 0
X_vac = [x]
Y_vac = [y]
#time parameters
t_vac = 0.01
while t_vac < tf and y_vac > -1:
    #Velocity Verlet Algorithm
    #1)New Position
    x_vac += vx_vac * t_vac
    y_vac += vy_vac * t_vac + (0.5 * -g * t_vac**2)
    X_vac.append(x_vac)
    Y_vac.append(y_vac)
    #2)New Velocity & Increment
    vy_vac = vy_vac + (t_vac * -g)
    t_vac += Δt

#===============================================================================


# This line makes Jupyter show animations inline as HTML widgets
plt.rcParams["animation.html"] = "jshtml"

X_cont = np.array(X_cont); Y_cont = np.array(Y_cont)
X_c = np.array(X_c); Y_c = np.array(Y_c) # ignoring variable atmospheric density w.r.t. altitude
X_vac = np.array(X_vac); Y_vac = np.array(Y_vac) # ignoring both drag & variable atmospheric density w.r.t. altitude


# Set up the figure
fig, ax = plt.subplots()
ax.set_title('Y {m} vs X {m}')
ax.grid(True)
ax.set_ylabel("Y {m}"); ax.set_xlabel("X {m}")
ax.axis([0, X_vac[-1], 0, Y_vac.max()])

trajectory_continuous, = ax.plot([], [], linestyle='--', linewidth=0.7, color='red')
sphere_continuous, = ax.plot([], [], 'o', markersize=3, alpha=0.5, color='red', label=r"$\vec{F}_g + \vec{F}_{D}(y)$")

trajectory_constant, = ax.plot([], [], linestyle='--',  linewidth=0.7, color='blue')
sphere_constant, = ax.plot([], [], 'o', markersize=3, alpha=0.5, color='blue', label=r"$\vec{F}_g + \vec{F}_{D}$")

trajectory, = ax.plot([], [], linestyle='--', linewidth=0.7, color='green')
sphere, = ax.plot([], [], 'o', markersize=3, alpha=0.5, color='green', label=r"$\vec{F}_g$")

ax.legend(loc='best')

# Animate function
def animate(_):
    trajectory_continuous.set_data(X_cont[:_], Y_cont[:_])
    sphere_continuous.set_data(X_cont[_-1:_], Y_cont[_-1:_])
    trajectory_constant.set_data(X_c[:_], Y_c[:_])
    sphere_constant.set_data(X_c[_-1:_], Y_c[_-1:_])
    trajectory.set_data(X_vac[:_], Y_vac[:_])
    sphere.set_data(X_vac[_-1:_], Y_vac[_-1:_])

    # note, need to end with ',' for single returned frame
    return (trajectory_continuous, sphere_continuous,
            trajectory_constant, sphere_constant,
            trajectory, sphere)

plt.close(fig)
ani = animation.FuncAnimation(fig, animate, frames=len(X_cont), interval=80, blit=True)
HTML(ani.to_jshtml())
# Out:
# <link rel="stylesheet"
# href="https://maxcdn.bootstrapcdn.com/font-awesome/4.4.0/css/font-awesome.min.css">
# <script language="javascript">
#   function isInternetExplorer() {
#     ua = navigator.userAgent;
#     /* MSIE used to detect old browsers and Trident used to newer ones*/
#     return ua.indexOf("MSIE ") > -1 || ua.indexOf("Trident/") > -1;
#   }
#
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     var slider = document.getElementById(this.slider_id);
#     slider.max = this.frames.length - 1;
#     if (isInternetExplorer()) {
#         // switch from oninput to onchange because IE <= 11 does not conform
#         // with W3C specification. It ignores oninput and onchange behaves
#         // like oninput. In contrast, Microsoft Edge behaves correctly.
#         slider.setAttribute('onchange', slider.getAttribute('oninput'));
#         slider.setAttribute('oninput', null);
#     }
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src =
#             this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#   }
#
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_forward();
#     }, this.interval);
#   }
#
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_reverse();
#     }, this.interval);
#   }
# </script>
#
# <style>
# .animation {
#     display: inline-block;
#     text-align: center;
# }
# input[type=range].anim-slider {
#     width: 374px;
#     margin-left: auto;
#     margin-right: auto;
# }
# .anim-buttons {
#     margin: 8px 0px;
# }
# .anim-buttons button {
#     padding: 0;
#     width: 36px;
# }
# .anim-state label {
#     margin-right: 8px;
# }
# .anim-state input {
#     margin: 0;
#     vertical-align: middle;
# }
# </style>
#
# <div class="animation">
#   <img id="_anim_img0d72764047fe4b8c891bff8664a86305">
#   <div class="anim-controls">
#     <input id="_anim_slider0d72764047fe4b8c891bff8664a86305" type="range" class="anim-slider"
#            name="points" min="0" max="1" step="1" value="0"
#            oninput="anim0d72764047fe4b8c891bff8664a86305.set_frame(parseInt(this.value));">
#     <div class="anim-buttons">
#       <button title="Decrease speed" aria-label="Decrease speed" onclick="anim0d72764047fe4b8c891bff8664a86305.slower()">
#           <i class="fa fa-minus"></i></button>
#       <button title="First frame" aria-label="First frame" onclick="anim0d72764047fe4b8c891bff8664a86305.first_frame()">
#         <i class="fa fa-fast-backward"></i></button>
#       <button title="Previous frame" aria-label="Previous frame" onclick="anim0d72764047fe4b8c891bff8664a86305.previous_frame()">
#           <i class="fa fa-step-backward"></i></button>
#       <button title="Play backwards" aria-label="Play backwards" onclick="anim0d72764047fe4b8c891bff8664a86305.reverse_animation()">
#           <i class="fa fa-play fa-flip-horizontal"></i></button>
#       <button title="Pause" aria-label="Pause" onclick="anim0d72764047fe4b8c891bff8664a86305.pause_animation()">
#           <i class="fa fa-pause"></i></button>
#       <button title="Play" aria-label="Play" onclick="anim0d72764047fe4b8c891bff8664a86305.play_animation()">
#           <i class="fa fa-play"></i></button>
#       <button title="Next frame" aria-label="Next frame" onclick="anim0d72764047fe4b8c891bff8664a86305.next_frame()">
#           <i class="fa fa-step-forward"></i></button>
#       <button title="Last frame" aria-label="Last frame" onclick="anim0d72764047fe4b8c891bff8664a86305.last_frame()">
#           <i class="fa fa-fast-forward"></i></button>
#       <button title="Increase speed" aria-label="Increase speed" onclick="anim0d72764047fe4b8c891bff8664a86305.faster()">
#           <i class="fa fa-plus"></i></button>
#     </div>
#     <form title="Repetition mode" aria-label="Repetition mode" action="#n" name="_anim_loop_select0d72764047fe4b8c891bff8664a86305"
#           class="anim-state">
#       <input type="radio" name="state" value="once" id="_anim_radio1_0d72764047fe4b8c891bff8664a86305"
#              >
#       <label for="_anim_radio1_0d72764047fe4b8c891bff8664a86305">Once</label>
#       <input type="radio" name="state" value="loop" id="_anim_radio2_0d72764047fe4b8c891bff8664a86305"
#              checked>
#       <label for="_anim_radio2_0d72764047fe4b8c891bff8664a86305">Loop</label>
#       <input type="radio" name="state" value="reflect" id="_anim_radio3_0d72764047fe4b8c891bff8664a86305"
#              >
#       <label for="_anim_radio3_0d72764047fe4b8c891bff8664a86305">Reflect</label>
#     </form>
#   </div>
# </div>
#
#
# <script language="javascript">
#   /* Instantiate the Animation class. */
#   /* The IDs given should match those used in the template above. */
#   (function() {
#     var img_id = "_anim_img0d72764047fe4b8c891bff8664a86305";
#     var slider_id = "_anim_slider0d72764047fe4b8c891bff8664a86305";
#     var loop_select_id = "_anim_loop_select0d72764047fe4b8c891bff8664a86305";
#     var frames = new Array(73);
#
#   frames[0] = "...\
# bGliIHZlcnNpb24zLjEwLjYsIGh0dHBzOi8vbWF0cGxvdGxpYi5vcmcvq6yFwwAAAAlwSFlzAAAP\
# YQAAD2EBqD+naQAARZZJR
