# %%
import importlib
import projectilemotion
importlib.reload(projectilemotion)
from projectilemotion import ProjectileMotion as PM

trajectory = PM(
    # time_step=0.01, # for smoother animation
    
    # comment both out for altitude-based drag
    # altitude_threshold=0, # for constant drag
    # viscosity=0, # for no drag
)
data = trajectory.data
print(f"λ = {trajectory.altitude_threshold} m.")
print(f"γ = {trajectory.viscosity} Ns²/m⁴.")
trajectory.animate()
# Out:
# λ = 10000.0 m.
# γ = 0.25 Ns²/m⁴.
